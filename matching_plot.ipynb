# %%
from folium import plugins
import json
import sys

x_min = 32.950424
y_min = 124.773835
x_max = 38.763189
y_max = 131.563393
x_d = x_max - x_min
y_d = y_max - y_min

h_x_d = 589*2 # 634은 우리나라 전체의 위도 거리 634km
h_y_d = 647*2

per_x_cell = x_d/h_x_d
per_y_cell = y_d/h_y_d

def read_seg():
    cell = {}
    link_id = {}
    with open("test.geojson", "r", encoding='UTF8') as f:
        count = 0
        while True :
            temp = set()
            line = f.readline()
            if not line: break
            if "fid" in line:
                try:
                    j = json.loads(line[:-2])
#                     print(j)
                except:
                    j = json.loads(line)
#                     print(j)
                link = j["properties"]["fid"]
                '''
                coordinates = j["geometry"]["coordinates"]
                for gps in coordinates[0]:
                    grid_x = int((gps[1]-x_min)/per_x_cell)
                    grid_y = int((gps[0]-y_min)/per_y_cell)
                    temp.add((grid_x*h_x_d)+grid_y)
                temp = list(temp)
                
                for cell_num in temp:
                    li = []
                    if not cell.get(cell_num):
                        cell[cell_num] = []
                    li = cell.get(cell_num)
                    li.append(link)
                    cell[cell_num] = li
                '''
                link_id[link] = j
    return cell, link_id

def Link_plot(result):
    temp = []
    color_data = ["red","black","blue","green","purple"]
    z = 0
    mapping_data = result
    map_osm = folium.Map(location = [37.566345, 126.977893], zoom_start = 11)
    for j in range(len(traj)):
        folium.Circle(traj[j], color = 'black', radius=1).add_to(map_osm)
    for i in mapping_data:
        for j in link_id[i]["geometry"]["coordinates"][0]:
            temp.append(j[::-1])
        plugins.PolyLineOffset(temp, color = color_data[z]).add_to(map_osm)
        temp = []
        t2l = list(mapping_data[i])
        if (t2l[1] - t2l[0])>1:
            plugins.PolyLineOffset(traj[t2l[0]:t2l[1]], color = color_data[z], offset=20).add_to(map_osm)
            z = z+1
        else:
            folium.Circle(traj[t2l[0]], color = color_data[z], radius=1).add_to(map_osm)
            z = z+1
        if z == 5:
            z=0
    return map_osm

def test_plot(result):
    print("mapmatching")
    print(len(result))
    temp = []
    mapping_data = result
    map_osm = folium.Map(location = [37.566345, 126.977893], zoom_start = 11)
    for j in range(len(traj)):
        folium.Circle(traj[j], color = 'black', radius=1).add_to(map_osm)
    for i in mapping_data:
        for j in link_id[i]["geometry"]["coordinates"][0]:
            temp.append(j[::-1])
        plugins.PolyLineOffset(temp, popup=i, color = "red").add_to(map_osm)
        print(i,temp[0], temp[-1])
        #print(i)
        temp = []

#         t2l = list(mapping_data[i])
#         if (t2l[1] - t2l[0])>1:
#             plugins.PolyLineOffset(traj[t2l[0]:t2l[1]], color = "red", offset=20).add_to(map_osm)
#         else:
#             folium.Circle(traj[t2l[0]], color = "red", radius=1).add_to(map_osm)
    return map_osm

def test_plot2(result):
    print("fmm")
    temp = []
    mapping_data = result
    map_osm = folium.Map(location = [41.162283, -8.60697], zoom_start = 11)
    for j in range(len(traj)):
        traj[j].reverse()
        folium.Circle(traj[j], color = 'black', radius=1).add_to(map_osm)
    data = mapping_data.replace("L","").replace(" ","").split(",")
    '''
    print(len(data))
    for i in data:
        for j in link_id[int(i)]["geometry"]["coordinates"]:
            temp.append(j[::-1])
        plugins.PolyLineOffset(temp, popup=i, color = "red").add_to(map_osm)
        print(i,temp[0], temp[-1])
        #print(i)
        temp = []
    '''

#         t2l = list(mapping_data[i])
#         if (t2l[1] - t2l[0])>1:
#             plugins.PolyLineOffset(traj[t2l[0]:t2l[1]], color = "red", offset=20).add_to(map_osm)
#         else:
#             folium.Circle(traj[t2l[0]], color = "red", radius=1).add_to(map_osm)
    return map_osm

# traj = []
# with open("POINT_20200925.txt","r", encoding='UTF8') as f:
#     for i in range(10):
#         line = f.readline()
#     line = line.split(',')
#     line = line[2:]
#     line = ",".join(line)
#     data = json.loads(line)
#     data = data["items"]

#     for i in data:
#         gps = []
#         lat = i["lat"]
#         lng = i["lng"]
#         gps = [lat,lng]
#         traj.append(gps)

import folium

data = "-0.201231:51.373521;-0.20278:51.3742;-0.2042:51.37485;-0.20406:51.37502;-0.20393:51.37518;-0.20382:51.37531;-0.20367:51.37554;-0.20354:51.37581;-0.20345:51.37608;-0.20341:51.3762;-0.20345:51.37634;-0.2034:51.37646;-0.20326:51.37673;-0.20311:51.37694;-0.20302:51.37705;-0.20292:51.37718;-0.20285:51.37726;-0.20271:51.37733;-0.20259:51.37747;-0.20246:51.37761;-0.2023:51.37776;-0.20215:51.3779;-0.20199:51.37803;-0.2017:51.37826;-0.20143:51.37844;-0.20111:51.37862;-0.20083:51.37877;-0.20055:51.37891;-0.19963:51.37939;-0.1993:51.37956;-0.19883:51.3798;-0.1975:51.3805;-0.19741:51.38055;-0.19726:51.38063;-0.19705:51.38074;-0.19684:51.38085;-0.19663:51.38096;-0.19634:51.38111;-0.19617:51.3812;-0.19605:51.38126;-0.1959:51.38134;-0.19561:51.38149;-0.19539:51.3816;-0.19483:51.38188;-0.19443:51.38209;-0.19337:51.38265;-0.19297:51.38286;-0.19269:51.383;-0.19245:51.38312;-0.19114:51.3838;-0.19084:51.38396;-0.1908:51.38403;-0.19066:51.3841;-0.19047:51.3842;-0.19046:51.38424;-0.19035:51.38437;-0.19012:51.38463;-0.19006:51.38469;-0.19:51.38473;-0.18995:51.38475;-0.18998:51.38496;-0.18996:51.38515;-0.18995:51.38519;-0.1898:51.38561;-0.18969:51.38602;-0.18951:51.38666;-0.1893:51.38745;-0.18913:51.38809;-0.18896:51.38876;-0.18889:51.38902;-0.1887:51.38975;-0.1886:51.39016;-0.1884:51.39091;-0.18802:51.3924;-0.18787:51.39301;-0.18776:51.39345;-0.18772:51.39358;-0.18762:51.39391;-0.18752:51.39423;-0.18733:51.39492;-0.18721:51.39538;-0.18717:51.39554;-0.18707:51.39598;-0.18703:51.39613;-0.18702:51.39617;-0.18694:51.39648;-0.18687:51.39671;-0.18681:51.39695;-0.18675:51.39716;-0.18673:51.39734;-0.18672:51.3975
fmm_C = '6681L, 6680L, 1811L, 1806L, 1810L, 10192L, 1801L, 10196L, 10198L, 1799L, 2092L, 1793L, 2058L, 2051L, 10369L, 1795L, 1233L, 5639L, 5642L, 7326L, 5635L, 10715L, 5634L, 5607L, 5613L, 5595L, 5602L, 10625L, 10626L, 5602L, 10625L, 10626L, 5601L, 5605L, 1186L, 1187L, 5041L, 5051L, 10412L, 5045L, 5610L, 10624L, 5609L, 5623L, 9543L, 1199L, 461L, 3098L, 7001L, 457L, 3030L, 7225L, 3032L, 3035L, 3032L, 3036L, 10516L, 3034L, 3037L, 3055L, 3057L, 3103L, 3099L, 458L, 1235L, 1247L, 1237L, 1240L, 1239L, 1242L, 9534L, 2820L, 1172L, 1247L, 1236L, 459L, 1198L, 9542L, 5625L, 5608L, 1225L, 1244L, 4827L, 1111L, 4827L, 1110L, 2834L, 2001L, 1114L, 10718L, 7330L, 1708L, 1835L, 1837L, 2073L, 5373L, 1846L, 1177L, 1709L, 7331L, 1115L, 1227L, 10627L, 5598L, 830L, 9327L, 5637L, 5631L, 5645L, 5545L, 1265L, 9933L, 1258L, 1260L, 2035L, 1229L, 1178L, 9499L, 5862L, 10533L, 1181L, 1271L, 8834L, 1269L, 1182L, 2296L, 1317L, 1185L, 1312L, 10480L, 8013L, 586L, 8011L, 8009L, 570L, 572L, 575L, 4622L, 10324L, 2029L, 1357L, 907L, 911L, 8352L, 432L, 5615L, 10312L, 10315L, 1329L, 5640L, 5622L, 5606L, 5604L, 5599L, 6678L, 1814L, 6681L, 6680L'
fmm_O = '6681L, 6680L, 1806L, 1806L, 1810L, 10192L, 10198L, 1799L, 1799L, 2058L, 1795L, 1795L, 1795L, 1233L, 5642L, 5634L, 5602L, 5602L, 5602L, 10625L, 10625L, 10625L, 10625L, 10625L, 5602L, 5602L, 5602L, 5601L, 5601L, 5601L, 5601L, 10412L, 10412L, 10412L, 10624L, 10624L, 5609L, 1199L, 7001L, 457L, 3030L, 3032L, 3035L, 3035L, 3032L, 3032L, 10516L, 10516L, 3034L, 3034L, 3037L, 3055L, 3055L, 3099L, 3099L, 1247L, 9534L, 1111L, 2001L, 10718L, 1846L, 1177L, 1177L, 1177L, 1177L, 1178L, 5862L, 10533L, 1181L, 8834L, 2296L, 1185L, 1185L, 1185L, 1185L, 1185L, 1185L, 10480L, 10480L, 10480L, 10480L, 10480L, 10480L, 8013L, 8013L, 8013L, 8009L, 8009L, 570L, 572L, 4622L, 1357L, 911L, 5615L, 5615L, 5615L, 5622L, 5599L, 5599L, 6681L, 6680L, 6680L, 6680L, 6680L, 6680L, 6680L, 6680L, 6680L, 6680L, 6680L, 6680L, 6680L, 6680L, 6680L, 6680L, 6680L'
fmm_X = '1L'
#cell, link_id = read_seg()


#m = test_plot(ourpropse)ㅌ
m = test_plot2(fmm_X)
#m = test_plot(ourpropse)

m
# Out:
# 600
# fmm
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
with open("test.geojson", "w", encoding='UTF8') as r:
    with open("porto.geojson", "r", encoding='UTF8') as f:
        count = 0
        line = f.read()
        data = line.replace("}},","}},\n")
        r.write(data)
